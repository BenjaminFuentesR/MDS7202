# %% [markdown]
# # **Laboratorio 8: Ready, Set, Deploy! 👩‍🚀👨‍🚀**
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Otoño 2026 </strong></center>
#
# ### Cuerpo Docente:
#
# - Profesores: Pablo Badilla, Diego Cortez
# - Auxiliares: Melanie Peña, Valentina Rojas
# - Ayudantes: Javiera Arévalo, Tamara Carrasco y Ignacio Reyes

# %% [markdown]
# ### Equipo: SUPER IMPORTANTE - notebooks sin nombre no serán revisados
#
# - Nombre de alumno 1: Ignacio Díaz C.
# - Nombre de alumno 2: Benjamín Fuentes R.
#
# ### **Link de repositorio de GitHub:**(https://github.com/BenjaminFuentesR/MDS7202)

# %% [markdown]
# ## Temas a tratar
#
# - Entrenamiento y registro de modelos usando MLFlow.
# - Despliegue de modelo usando FastAPI
# - Containerización del proyecto usando Docker
#
# ### Objetivos principales del laboratorio
#
# - Generar una solución a un problema a partir de ML
# - Desplegar su solución usando MLFlow, FastAPI y Docker
#
# El laboratorio deberá ser desarrollado sin el uso indiscriminado de iteradores nativos de python (aka "for", "while"). La idea es que aprendan a exprimir al máximo las funciones optimizadas que nos entrega `pandas`, las cuales vale mencionar, son bastante más eficientes que los iteradores nativos sobre DataFrames.

# %% [markdown]
# # **Introducción**

# %% [markdown]
# <p align="center">
#   <img src="https://media.giphy.com/media/v1.Y2lkPTc5MGI3NjExODJnMHJzNzlkNmQweXoyY3ltbnZ2ZDlxY2c0aW5jcHNzeDNtOXBsdCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/AbPdhwsMgjMjax5reo/giphy.gif" width="400">
# </p>

# %% [markdown]
# Consumida en la tristeza el despido de Renacín, Smapina ha decaído en su desempeño, lo que se ha traducido en un irregular tratamiento del agua. Esto ha implicado una baja en la calidad del agua, llegando a haber algunos puntos de la comuna en la que el vital elemento no es apto para el consumo humano. Es por esto que la sanitaria pública de la municipalidad de Maipú se ha contactado con ustedes para que le entreguen una urgente solución a este problema (a la vez que dejan a Smapina, al igual que Renacín, sin trabajo 😔).
#
# El problema que la empresa le ha solicitado resolver es el de elaborar un sistema que les permita saber si el agua es potable o no. Para esto, la sanitaria les ha proveido una base de datos con la lectura de múltiples sensores IOT colocados en diversas cañerías, conductos y estanques. Estos sensores señalan nueve tipos de mediciones químicas y más una etiqueta elaborada en laboratorio que indica si el agua es potable o no el agua.
#
# La idea final es que puedan, en el caso que el agua no sea potable, dar un aviso inmediato para corregir el problema. Tenga en cuenta que parte del equipo docente vive en Maipú y su intoxicación podría implicar graves problemas para el cierre del curso.
#
# Atributos:
#
# 1. pH value
# 2. Hardness
# 3. Solids (Total dissolved solids - TDS)
# 4. Chloramines
# 5. Sulfate
# 6. Conductivity
# 7. Organic_carbon
# 8. Trihalomethanes
# 9. Turbidity
#
# Variable a predecir:
#
# 10. Potability (1 si es potable, 0 no potable)
#
# Descripción de cada atributo se pueden encontrar en el siguiente link: [dataset](https://www.kaggle.com/adityakadiwal/water-potability)

# %% [markdown]
# # **1. Optimización de modelos con Optuna + MLFlow (2.0 puntos)**
#
# El objetivo de esta sección es que ustedes puedan combinar Optuna con MLFlow para poder realizar la optimización de los hiperparámetros de sus modelos.
#
# Como aún no hemos hablado nada sobre `MLFlow` cabe preguntarse: **¡¿Qué !"#@ es `MLflow`?!**
#
# <p align="center">
#   <img src="https://media.tenor.com/eusgDKT4smQAAAAC/matthew-perry-chandler-bing.gif" width="400">
# </p>
#
# ## **MLFlow**
#
# `MLflow` es una plataforma de código abierto que simplifica la gestión y seguimiento de proyectos de aprendizaje automático. Con sus herramientas, los desarrolladores pueden organizar, rastrear y comparar experimentos, además de registrar modelos y controlar versiones.
#
# <p align="center">
#   <img src="https://spark.apache.org/images/mlflow-logo.png" width="350">
# </p>
#
# Si bien esta plataforma cuenta con un gran número de herramientas y funcionalidades, en este laboratorio trabajaremos con dos:
# 1. **Runs**: Registro que constituye la información guardada tras la ejecución de un entrenamiento. Cada `run` tiene su propio run_id, el cual sirve como identificador para el entrenamiento en sí mismo. Dentro de cada `run` podremos acceder a información como los hiperparámetros utilizados, las métricas obtenidas, las librerías requeridas y hasta nos permite descargar el modelo entrenado.
# 2. **Experiments**: Se utilizan para agrupar y organizar diferentes ejecuciones de modelos (`runs`). En ese sentido, un experimento puede agrupar 1 o más `runs`. De esta manera, es posible también registrar métricas, parámetros y archivos (artefactos) asociados a cada experimento.
#
# ### **Todo bien pero entonces, ¿cómo se usa en la práctica `MLflow`?**
#
# Es sencillo! Considerando un problema de machine learning genérico, podemos registrar la información relevante del entrenamiento ejecutando `mlflow.autolog()` antes entrenar nuestro modelo. Veamos este bonito ejemplo facilitado por los mismos creadores de `MLflow`:
#
# ```python
# #!pip install mlflow
# import mlflow # importar mlflow
#
# from sklearn.model_selection import train_test_split
# from sklearn.datasets import load_diabetes
# from sklearn.ensemble import RandomForestRegressor
#
# db = load_diabetes()
# X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)
#
# # Create and train models.
# rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
#
# mlflow.autolog() # registrar automáticamente información del entrenamiento
# with mlflow.start_run(): # delimita inicio y fin del run
#     # aquí comienza el run
#     rf.fit(X_train, y_train) # train the model
#     predictions = rf.predict(X_test) # Use the model to make predictions on the test dataset.
#     # aquí termina el run
# ```
#
# Si ustedes ejecutan el código anterior en sus máquinas locales (desde un jupyter notebook por ejemplo) se darán cuenta que en su directorio *root* se ha creado la carpeta `mlruns`. Esta carpeta lleva el tracking de todos los entrenamientos ejecutados desde el directorio root (importante: si se cambian de directorio y vuelven a ejecutar el código anterior, se creará otra carpeta y no tendrán acceso al entrenamiento anterior). Para visualizar estos entrenamientos, `MLflow` nos facilita hermosa interfaz visual a la que podemos acceder ejecutando:
#
# ```
# mlflow ui
# ```
#
# y luego pinchando en la ruta http://127.0.0.1:5000 que nos retorna la terminal. Veamos en vivo algunas de sus funcionalidades!
#
# <p align="center">
#   <img src="https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExZXVuM3A5MW1heDFpa21qbGlwN2pyc2VoNnZsMmRzODZxdnluemo2bCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/3o84sq21TxDH6PyYms/giphy.gif" width="400">
# </p>
#
# Les dejamos también algunos comandos útiles:
#
# - `mlflow.create_experiment("nombre_experimento")`: Les permite crear un nuevo experimento para agrupar entrenamientos
# - `mlflow.log_metric("nombre_métrica", métrica)`: Les permite registrar una métrica *custom* bajo el nombre de "nombre_métrica"

# %%
# !uv add mlflow

# %% [markdown]
# Si tiene problemas puede necesitar ejecutar `uv add "setuptools<82.0.0"`

# %%
import mlflow # importar mlflow

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.ensemble import RandomForestRegressor

db = load_diabetes()
X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

# Create and train models.
rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)

mlflow.autolog() # registrar automáticamente información del entrenamiento
with mlflow.start_run(): # delimita inicio y fin del run
    # aquí comienza el run
    rf.fit(X_train, y_train) # train the model
    predictions = rf.predict(X_test) # Use the model to make predictions on the test dataset.
    # aquí termina el run

# %%
run = mlflow.last_active_run()
info = mlflow.get_run(run.info.run_id)
print(info.data.params)
print(info.data.metrics)

# %% [markdown]
# ## **1.1 Combinando Optuna + MLflow (2.0 puntos)**
#
# Ahora que tenemos conocimiento de ambas herramientas, intentemos ahora combinarlas para **más sabor**. El objetivo de este apartado es simple: automatizar la optimización de los parámetros de nuestros modelos usando `Optuna` y registrando de forma automática cada resultado en `MLFlow`.
#
# Considerando el objetivo planteado, se le pide completar la función `optimize_model`, la cual debe:
# - **Optimizar los hiperparámetros del modelo `XGBoost` usando `Optuna`.** Realice una cantidad de iteraciones para evitar tiempos de ejecución excesivos (al menos 10)
# - **Registrar cada entrenamiento en un experimento nuevo**, asegurándose de que la métrica `f1-score` se registre como `"valid_f1"`. No se deben guardar todos los experimentos en *Default*; en su lugar, cada `experiment` y `run` deben tener nombres interpretables, reconocibles y diferentes a los nombres por defecto (por ejemplo, para un run: "XGBoost con lr 0.1").
# - **Devolver el mejor modelo** usando la función `get_best_model` y serializarlo en el disco con `pickle.dump`. Luego, guardar el modelo en la carpeta `/models`.
# - **Guardar el código en `optimize.py`**. La ejecución de `python optimize.py` debería ejecutar la función `optimize_model`.
# - **Guardar las versiones de las librerías utilizadas** en el desarrollo.
#
# *Hint: Le puede ser útil revisar los parámetros que recibe `mlflow.start_run`*
#
# ```python
# def get_best_model(experiment_id):
#     runs = mlflow.search_runs(experiment_id)
#     best_model_id = runs.sort_values("metrics.valid_f1")["run_id"].iloc[0]
#     best_model = mlflow.sklearn.load_model("runs:/" + best_model_id + "/model")
#
#     return best_model
# ```

# %%
from optimize import optimize_model
optimize_model()
# Out:
# 2026/06/10 20:14:38 INFO mlflow.tracking.fluent: Experiment with name 'Water Potability XGBoost' does not exist. Creating a new experiment.
#   0%|          | 0/20 [00:00<?, ?it/s]
# 2026/06/10 20:14:38 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:14:38 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:14:39 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 20:14:46 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:14:46 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:14:46 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 20:14:52 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:14:52 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:14:52 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 20:14:58 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:14:58 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:14:58 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 20:15:04 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:15:04 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:15:04 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 20:15:10 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:15:10 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:15:11 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 20:15:16 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:15:16 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:15:17 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 20:15:22 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:15:22 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:15:23 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 20:15:28 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:15:28 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:15:29 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 20:15:34 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:15:34 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:15:35 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 20:15:40 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:15:41 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:15:41 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 20:15:47 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:15:47 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:15:48 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 20:15:53 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:15:53 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:15:54 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 20:15:59 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:15:59 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:15:59 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 20:16:05 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:16:05 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:16:06 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 20:16:11 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:16:11 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:16:12 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 20:16:17 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:16:17 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:16:18 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 20:16:23 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:16:23 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:16:24 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 20:16:30 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:16:30 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:16:30 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/10 20:16:36 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/06/10 20:16:36 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2026/06/10 20:16:37 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Mejor F1: 0.5435
# Mejores hiperparámetros: {'n_estimators': 241, 'max_depth': 6, 'learning_rate': 0.021926448883593876, 'subsample': 0.52232009950186, 'colsample_bytree': 0.9263651707365782, 'reg_alpha': 4.98728720480702e-06, 'reg_lambda': 0.05929488320067802}
# 2026/06/10 20:16:45 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'dfbbd2de42104582b4fe1e5befd61b39', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2026/06/10 20:16:45 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# Plots guardados en plots/
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]
# Modelo guardado en models/xgb_20260610.pkl
# requirements.txt generado con uv export

# %% [markdown]
# # **2. FastAPI (2.0 puntos)**
#
# <div align="center">
#   <img src="https://media3.giphy.com/media/YQitE4YNQNahy/giphy-downsized-large.gif" width="500">
# </div>
#
# Con el modelo ya entrenado, la idea de esta sección es generar una API REST a la cual se le pueda hacer *requests* para así interactuar con su modelo. En particular, se le pide:
#
# - Guardar el código de esta sección en el archivo `main.py`. Note que ejecutar `python main.py` debería levantar el servidor en el puerto por defecto.
# - Defina `GET` con ruta tipo *home* que describa brevemente su modelo, el problema que intenta resolver, su entrada y salida.
# - Defina un `POST` a la ruta `/potabilidad/` donde utilice su mejor optimizado para predecir si una medición de agua es o no potable. Por ejemplo, una llamada de esta ruta con un *body*:
#
# ```json
# {
#    "ph":10.316400384553162,
#    "Hardness":217.2668424334475,
#    "Solids":10676.508475429378,
#    "Chloramines":3.445514571005745,
#    "Sulfate":397.7549459751925,
#    "Conductivity":492.20647361771086,
#    "Organic_carbon":12.812732207582542,
#    "Trihalomethanes":72.28192021570328,
#    "Turbidity":3.4073494284238364
# }
# ```
#
# Su servidor debería retornar una respuesta HTML con código 200 con:
#
#
# ```json
# {
#   "potabilidad": 0 # respuesta puede variar según el clasificador que entrenen
# }
# ```
#
# **`HINT:` Recuerde que puede utilizar [http://localhost:8000/docs](http://localhost:8000/docs) para hacer un `POST`.**

# %% [markdown]
# # **3. Docker (2 puntos)**

# %% [markdown]
# <div align="center">
#   <img src="https://miro.medium.com/v2/resize:fit:1400/1*9rafh2W0rbRJIKJzqYc8yA.gif" width="500">
# </div>

# %% [markdown]
# Tras el éxito de su aplicación web para generar la salida, Smapina le solicita que genere un contenedor para poder ejecutarla en cualquier computador de la empresa de agua potable.
#
# ## **3.1 Creación de Container (1 punto)**
#
# Cree un Dockerfile que use una imagen base de Python, copie los archivos del proyecto e instale las dependencias desde un `requirements.txt`. Con esto, construya y ejecute el contenedor Docker para la API configurada anteriormente. Entregue el código fuente (incluyendo `main.py`, `requirements.txt`, y `Dockerfile`) y la imagen Docker de la aplicación. Para la dockerización, asegúrese de cumplir con los siguientes puntos:
#
# 1. **Generar un archivo `.dockerignore`** que ignore carpetas y archivos innecesarios dentro del contenedor.
# 2. **Configurar un volumen** que permita la persistencia de los datos en una ruta local del computador.
# 3. **Exponer el puerto** para acceder a la ruta de la API sin tener que entrar al contenedor directamente.
# 4. **Incluir imágenes en el notebook** que muestren la ejecución del contenedor y los resultados obtenidos.
# 5. **Revisar y comentar los recursos utilizados por el contenedor**. Analice si los contenedores son livianos en términos de recursos.
#
# ## **3.2 Preguntas de Smapina (1 punto)**
# Tras haber experimentado con Docker, Smapina desea profundizar más en el tema y decide realizarle las siguientes consultas:
#
# - ¿Cómo se diferencia Docker de una máquina virtual (VM)?
# - ¿Cuál es la diferencia entre usar Docker y ejecutar la aplicación directamente en el sistema local?
# - ¿Cómo asegura Docker la consistencia entre diferentes entornos de desarrollo y producción?
# - ¿Cómo se gestionan los volúmenes en Docker para la persistencia de datos?
# - ¿Qué son Dockerfile y docker-compose.yml, y cuál es su propósito?

# %%
# Se grafican las imágenes capturadas del proceso.
from PIL import Image
import matplotlib.pyplot as plt

example = Image.open("plots/docker_example.png")
running = Image.open("plots/docker_running.png")
stats = Image.open("plots/docker_stats.png")
terminal = Image.open("plots/docker_terminal.png")
lista_img = [example, running, stats, terminal]

print("Primera Imagen: API con ejemplo de uso.")
print("Segunda Imagen: Logs en Docker desktop del contenedor corriendo.")
print("Tercera Imagen: Recursos utilizados del contenedor corriendo.")
print("Cuarta Imagen: Logs en terminal del contenedor corriendo")

fig, axes = plt.subplots(2, 2, figsize=(10, 10))
axes = axes.flatten()

for i in range(4):
    axes[i].imshow(lista_img [i])
    axes[i].axis('off')  # Oculta los ejes (ticks)

plt.tight_layout()

plt.show()
# Out:
# Primera Imagen: API con ejemplo de uso.
# Segunda Imagen: Logs en Docker desktop del contenedor corriendo.
# Tercera Imagen: Recursos utilizados del contenedor corriendo.
# Cuarta Imagen: Logs en terminal del contenedor corriendo

# %% [markdown]
# Se puede notar que recursos utilizados por el contenedor son mínimos. Un 0.16% de uso en CPU y un 1.68% (128MB) en memoria casi no afectan al rendimiento del computador. Por otro lado, la cantidad de información que se transmite en red (1.17KB) o en disco (3.78MB) son igual de irrelevantes en temas generales. Estos resultados reflejan una de las características de los contenedores, y es que usan muy poco recursos, en especial para tareas simples de este tipo, contrario a crear una maquina virtual que necesitan de la instalación e inicialización de un sistema operativo.

# %% [markdown]
# Respuestas 3.2
#
# 1. ¿Cómo se diferencia Docker de una máquina virtual (VM)?
# Existen tres grandes diferencias entre los dockers y las maquinas virtuales:
#
#     - En primer lugar, los dockers solamente empaquetan las aplicaciones y sus dependencias específicas lo que disminuye drásticamente el espacio necesario en disco, a diferencia de las maquinas virtuales que necesitan una copia completa del sistema operativo.
#     - En segundo lugar, los contenedores se construyen a partir de imágenes ligeras y archivos de configuración (gestionados por un motor de contenedores), lo que es más sencillo y rápido de implementar a diferencia de las maquinas virtuales que necesitan hipervisores para instalar un sistema operativo desde cero.
#     - Por último, en temas de velocidad de iniciación, los contenedores al compartir el núcleo del sistema operativo del host se inician de forma muy rápida, mientras que las maquinas virtuales pueden tardar varios mínutos al tener que inicializar un sistema operativo completo.
#
# 2. ¿Cuál es la diferencia entre usar Docker y ejecutar la aplicación directamente en el sistema local?:
# Al ejecutar una aplicación directamente en tu sistema local, dependes de la configuración de tu máquina, sus versiones y tipo de software, lo que puede causar errores de compatibilidad en otras pc. Docker en cambio, encapsula la app con su propio sistema operativo y librerías en un entorno aislado, asegurando que funcione casi igual en cualquier lado, teniendo como única diferencia el hardware del equipo.
#
# 3.  ¿Cómo asegura Docker la consistencia entre diferentes entornos de desarrollo y producción?:
# Para asegurar la consistencia entre diferentes entornos, Docker reúne el código, las librerías exactas y el sistema operativo en un solo paquete. Al hacer esto, minimiza las diferencias entre entornos y garantiza que la aplicación se ejecute exactamente igual en cualquier lado.
#
# 4. ¿Cómo se gestionan los volúmenes en Docker para la persistencia de datos?:
# Los volúmenes se gestionan enlazando de forma directa una carpeta de la máquina del host con una carpeta dentro del contenedor. Esto permite que los archivos se guarden fuera del contenedor, logrando que los datos no se pierdan aun si el contenedor deja de funcionar.
#
# 5. ¿Qué son Dockerfile y docker-compose.yml, y cuál es su propósito?:
# Dockerfile es un archivo de texto con instrucciones que definen como se construye una imagen personalizada de un docker. docker-compose.yml en cambio es un archivo en formato YAML cuyo proposito es configurar, orquestar y encender múltiples contenedores a la vez con un solo comando.

# %% [markdown]
# # Conclusión
#
# Éxito!
# <div align="center">
#   <img src="https://i.pinimg.com/originals/55/f5/fd/55f5fdc9455989f8caf7fca7f93bd96a.gif" width="500">
# </div>
